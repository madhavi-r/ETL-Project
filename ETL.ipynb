# %% [markdown]
# # ETL Project
# #### Group: Madhavi Raghunath, Matthew Lombardo, Meenakshi Kavaseri, Michael Oristano,John Bibbons

# %%
import pandas as pd

# %% [markdown]
# ## === Diversity Dataset ===

# %%
diversity_csv = "Resources/diversityindex.csv"
diversity_df = pd.read_csv(diversity_csv)
diversity_df.head()
# Out:
#                          Location  Diversity-Index  \
# 0  Aleutians West Census Area, AK         0.769346
# 1               Queens County, NY         0.742224
# 2                 Maui County, HI         0.740757
# 3              Alameda County, CA         0.740399
# 4      Aleutians East Borough, AK         0.738867
#
#    Black or African American alone, percent, 2013  \
# 0                                             7.4
# 1                                            20.9
# 2                                             0.8
# 3                                            12.4
# 4                                             7.7
#
#    American Indian and Alaska Native alone, percent, 2013  \
# 0                                               13.8
# 1                                                1.3
# 2                                                0.6
# 3                                                1.2
# 4                                               21.8
#
#    Asian alone, percent, 2013  \
# 0                        31.1
# 1                        25.2
# 2                        28.8
# 3                        28.2
# 4                        41.4
#
#    Native Hawaiian and Other Pacific Islander alone, percent,  \
# 0                                                2.3
# 1                                                0.2
# 2                                               10.6
# 3                                                1.0
# 4                                                0.7
#
#    Two or More Races, percent, 2013  Hispanic or Latino, percent, 2013  \
# 0                               4.8                               14.6
# 1                               2.7                               28.0
# 2                              23.3                               10.7
# 3                               5.2                               22.7
# 4                               3.7                               13.5
#
#    White alone, not Hispanic or Latino, percent, 2013
# 0                                               29.2
# 1                                               26.7
# 2                                               31.5
# 3                                               33.2
# 4                                               12.9

# %%
new_df = diversity_df

# %%
new_df['County'],new_df['State'] = diversity_df['Location'].str.rsplit(', ').str
new_df.head()
# Out:
#                          Location  Diversity-Index  \
# 0  Aleutians West Census Area, AK         0.769346
# 1               Queens County, NY         0.742224
# 2                 Maui County, HI         0.740757
# 3              Alameda County, CA         0.740399
# 4      Aleutians East Borough, AK         0.738867
#
#    Black or African American alone, percent, 2013  \
# 0                                             7.4
# 1                                            20.9
# 2                                             0.8
# 3                                            12.4
# 4                                             7.7
#
#    American Indian and Alaska Native alone, percent, 2013  \
# 0                                               13.8
# 1                                                1.3
# 2                                                0.6
# 3                                                1.2
# 4                                               21.8
#
#    Asian alone, percent, 2013  \
# 0                        31.1
# 1                        25.2
# 2                        28.8
# 3                        28.2
# 4                        41.4
#
#    Native Hawaiian and Other Pacific Islander alone, percent,  \
# 0                                                2.3
# 1                                                0.2
# 2                                               10.6
# 3                                                1.0
# 4                                                0.7
#
#    Two or More Races, percent, 2013  Hispanic or Latino, percent, 2013  \
# 0                               4.8                               14.6
# 1                               2.7                               28.0
# 2                              23.3                               10.7
# 3                               5.2                               22.7
# 4                               3.7                               13.5
#
#    White alone, not Hispanic or Latino, percent, 2013  \
# 0                                               29.2
# 1                                               26.7
# 2                                               31.5
# 3                                               33.2
# 4                                               12.9
#
#                        County State
# 0  Aleutians West Census Area    AK
# 1               Queens County    NY
# 2                 Maui County    HI
# 3              Alameda County    CA
# 4      Aleutians East Borough    AK

# %%
new_df2 = pd.DataFrame({"Diversity-Index":new_df.groupby(["State","County"])["Diversity-Index"].mean(),
                       "Black":new_df.groupby(["State","County"])["Black or African American alone, percent, 2013"].mean(),
                       "American Indian":new_df.groupby(["State","County"])["American Indian and Alaska Native alone, percent, 2013"].mean(),
                       "Asian":new_df.groupby(["State","County"])["Asian alone, percent, 2013"].mean(),
                       "Native Hawaiian":new_df.groupby(["State","County"])["Native Hawaiian and Other Pacific Islander alone, percent,"].mean(),
                       "Two or More Races":new_df.groupby(["State","County"])["Two or More Races, percent, 2013"].mean(),
                       "Hispanic/ Latino":new_df.groupby(["State","County"])["Hispanic or Latino, percent, 2013"].mean(),
                       "White":new_df.groupby(["State","County"])["White alone, not Hispanic or Latino, percent, 2013"].mean()})

# %%
new_df2.head()
# Out:
#                                   Diversity-Index  Black  American Indian  \
# State County
# AK    Aleutians East Borough             0.738867    7.7             21.8
#       Aleutians West Census Area         0.769346    7.4             13.8
#       Anchorage Municipality             0.601515    6.3              8.1
#       Bethel Census Area                 0.315556    0.7             81.8
#       Bristol Bay Borough                0.648271    0.0             33.8
#
#                                   Asian  Native Hawaiian  Two or More Races  \
# State County
# AK    Aleutians East Borough       41.4              0.7                3.7
#       Aleutians West Census Area   31.1              2.3                4.8
#       Anchorage Municipality        8.9              2.3                7.8
#       Bethel Census Area            1.0              0.3                4.1
#       Bristol Bay Borough           1.1              0.3               17.5
#
#                                   Hispanic/ Latino  White
# State County
# AK    Aleutians East Borough                  13.5   12.9
#       Aleutians West Census Area              14.6   29.2
#       Anchorage Municipality                   8.6   60.5
#       Bethel Census Area                       1.6   11.5
#       Bristol Bay Borough                      3.9   45.3

# %% [markdown]
# ## === Unemployment Rate Dataset ===

# %%
unemp_df = pd.read_csv('Resources/output.csv')
unemp_df.head()
# Out:
#    Year     Month        State         County  Rate
# 0  2015  February  Mississippi  Newton County   6.1
# 1  2015  February  Mississippi  Panola County   9.4
# 2  2015  February  Mississippi  Monroe County   7.9
# 3  2015  February  Mississippi   Hinds County   6.1
# 4  2015  February  Mississippi  Kemper County  10.6

# %%
unemp_df = unemp_df[['County', "State", 'Rate']].copy()
unemp_df.head()
# Out:
#           County        State  Rate
# 0  Newton County  Mississippi   6.1
# 1  Panola County  Mississippi   9.4
# 2  Monroe County  Mississippi   7.9
# 3   Hinds County  Mississippi   6.1
# 4  Kemper County  Mississippi  10.6

# %%
us_state_abbrev = {
   'Alabama': 'AL',
   'Alaska': 'AK',
   'Arizona': 'AZ',
   'Arkansas': 'AR',
   'California': 'CA',
   'Colorado': 'CO',
   'Connecticut': 'CT',
   'Delaware': 'DE',
   'Florida': 'FL',
   'Georgia': 'GA',
   'Hawaii': 'HI',
   'Idaho': 'ID',
   'Illinois': 'IL',
   'Indiana': 'IN',
   'Iowa': 'IA',
   'Kansas': 'KS',
   'Kentucky': 'KY',
   'Louisiana': 'LA',
   'Maine': 'ME',
   'Maryland': 'MD',
   'Massachusetts': 'MA',
   'Michigan': 'MI',
   'Minnesota': 'MN',
   'Mississippi': 'MS',
   'Missouri': 'MO',
   'Montana': 'MT',
   'Nebraska': 'NE',
   'Nevada': 'NV',
   'New Hampshire': 'NH',
   'New Jersey': 'NJ',
   'New Mexico': 'NM',
   'New York': 'NY',
   'North Carolina': 'NC',
   'North Dakota': 'ND',
   'Ohio': 'OH',
   'Oklahoma': 'OK',
   'Oregon': 'OR',
   'Pennsylvania': 'PA',
   'Rhode Island': 'RI',
   'South Carolina': 'SC',
   'South Dakota': 'SD',
   'Tennessee': 'TN',
   'Texas': 'TX',
   'Utah': 'UT',
   'Vermont': 'VT',
   'Virginia': 'VA',
   'Washington': 'WA',
   'West Virginia': 'WV',
   'Wisconsin': 'WI',
   'Wyoming': 'WY',
}

# %%
unemp_df2 = unemp_df

# %%
for key, value in us_state_abbrev.items():
    unemp_df2.loc[unemp_df2['State']==key,'State'] = value

# %%
unemp_df2.head()
# Out:
#           County State  Rate
# 0  Newton County    MS   6.1
# 1  Panola County    MS   9.4
# 2  Monroe County    MS   7.9
# 3   Hinds County    MS   6.1
# 4  Kemper County    MS  10.6

# %%
unemp_df_new = pd.DataFrame({"Unemployment Rate":unemp_df2.groupby(["State","County"])["Rate"].mean()})

# %%
unemp_df_new.head()
# Out:
#                       Unemployment Rate
# State County
# AL    Autauga County           5.417284
#       Baldwin County           5.364198
#       Barbour County           8.460185
#       Bibb County              7.684877
#       Blount County            5.164506

# %% [markdown]
# ## === Median Income & Population Dataset ===

# %%
median_inc = pd.read_csv('Resources/2015 Median Income by County.csv')
median_inc.head()
# Out:
#               County-State          County  Population  \
# 0  Autauga County, Alabama  Autauga County       55221
# 1  Baldwin County, Alabama  Baldwin County      195121
# 2  Barbour County, Alabama  Barbour County       26932
# 3     Bibb County, Alabama     Bibb County       22604
# 4   Blount County, Alabama   Blount County       57710
#
#    Median household income State Code    State
# 0                  51281.0         AL  Alabama
# 1                  50254.0         AL  Alabama
# 2                  32964.0         AL  Alabama
# 3                  38678.0         AL  Alabama
# 4                  45813.0         AL  Alabama

# %%
median_inc = median_inc[['County',"State Code", 'Population',"Median household income"]]
median_inc.head()
# Out:
#            County State Code  Population  Median household income
# 0  Autauga County         AL       55221                  51281.0
# 1  Baldwin County         AL      195121                  50254.0
# 2  Barbour County         AL       26932                  32964.0
# 3     Bibb County         AL       22604                  38678.0
# 4   Blount County         AL       57710                  45813.0

# %%
median_inc = median_inc.rename(columns={"State Code": "State"})

# %%
median_inc_new = pd.DataFrame({"Median household income":median_inc.groupby(["State","County"])["Median household income"].mean(),
                              "Population":median_inc.groupby(["State","County"])["Population"].sum()})

# %%
median_inc_new.head()
# Out:
#                                   Median household income  Population
# State County
# AK    Aleutians East Borough                      61518.0        3304
#       Aleutians West Census Area                  84306.0        5684
#       Anchorage Municipality                      78326.0      299107
#       Bethel Census Area                          51012.0       17776
#       Bristol Bay Borough                         79750.0         970

# %% [markdown]
# ## === Merging Datasets ===

# %%
merged = pd.merge(unemp_df_new,median_inc_new, on=["State",'County'],how="inner")

# %%
merged.head()
# Out:
#                       Unemployment Rate  Median household income  Population
# State County
# AL    Autauga County           5.417284                  51281.0       55221
#       Baldwin County           5.364198                  50254.0      195121
#       Barbour County           8.460185                  32964.0       26932
#       Bibb County              7.684877                  38678.0       22604
#       Blount County            5.164506                  45813.0       57710

# %%
merged2 = pd.merge(merged,new_df2, on=["State",'County'],how="inner")

# %%
merged2.head()
# Out:
#                       Unemployment Rate  Median household income  Population  \
# State County
# AL    Autauga County           5.417284                  51281.0       55221
#       Baldwin County           5.364198                  50254.0      195121
#       Barbour County           8.460185                  32964.0       26932
#       Bibb County              7.684877                  38678.0       22604
#       Blount County            5.164506                  45813.0       57710
#
#                       Diversity-Index  Black  American Indian  Asian  \
# State County
# AL    Autauga County         0.388898   18.4              0.5    1.1
#       Baldwin County         0.297942    9.5              0.7    0.9
#       Barbour County         0.556605   47.6              0.6    0.5
#       Bibb County            0.394100   22.1              0.4    0.2
#       Blount County          0.221056    1.8              0.6    0.3
#
#                       Native Hawaiian  Two or More Races  Hispanic/ Latino  \
# State County
# AL    Autauga County              0.1                1.7               2.7
#       Baldwin County              0.1                1.5               4.6
#       Barbour County              0.2                0.9               4.8
#       Bibb County                 0.1                0.9               2.1
#       Blount County               0.1                1.1               8.7
#
#                       White
# State County
# AL    Autauga County   75.9
#       Baldwin County   83.1
#       Barbour County   46.3
#       Bibb County      74.6
#       Blount County    87.8

# %%
merged_final = merged2.reset_index()

# %%
merged_final.head()
# Out:
#   State          County  Unemployment Rate  Median household income  \
# 0    AL  Autauga County           5.417284                  51281.0
# 1    AL  Baldwin County           5.364198                  50254.0
# 2    AL  Barbour County           8.460185                  32964.0
# 3    AL     Bibb County           7.684877                  38678.0
# 4    AL   Blount County           5.164506                  45813.0
#
#    Population  Diversity-Index  Black  American Indian  Asian  \
# 0       55221         0.388898   18.4              0.5    1.1
# 1      195121         0.297942    9.5              0.7    0.9
# 2       26932         0.556605   47.6              0.6    0.5
# 3       22604         0.394100   22.1              0.4    0.2
# 4       57710         0.221056    1.8              0.6    0.3
#
#    Native Hawaiian  Two or More Races  Hispanic/ Latino  White
# 0              0.1                1.7               2.7   75.9
# 1              0.1                1.5               4.6   83.1
# 2              0.2                0.9               4.8   46.3
# 3              0.1                0.9               2.1   74.6
# 4              0.1                1.1               8.7   87.8

# %%
merged_final = merged_final[["State","County","Population","Median household income","Unemployment Rate",
                            "Diversity-Index","White","Black","Hispanic/ Latino","Asian","American Indian",
                            "Native Hawaiian","Two or More Races"]]

# %%
merged_final
# Out:
#      State              County  Population  Median household income  \
# 0       AL      Autauga County       55221                  51281.0
# 1       AL      Baldwin County      195121                  50254.0
# 2       AL      Barbour County       26932                  32964.0
# 3       AL         Bibb County       22604                  38678.0
# 4       AL       Blount County       57710                  45813.0
# 5       AL      Bullock County       10678                  31938.0
# 6       AL       Butler County       20354                  32229.0
# 7       AL      Calhoun County      116648                  41703.0
# 8       AL     Chambers County       34079                  34177.0
# 9       AL     Cherokee County       26008                  36296.0
# 10      AL      Chilton County       43819                  41627.0
# 11      AL      Choctaw County       13395                  33536.0
# 12      AL       Clarke County       25070                  32011.0
# 13      AL         Clay County       13537                  35327.0
# 14      AL     Cleburne County       15002                  38056.0
# 15      AL       Coffee County       50884                  46729.0
# 16      AL      Colbert County       54444                  40576.0
# 17      AL      Conecuh County       12865                  24900.0
# 18      AL        Coosa County       11027                  31212.0
# 19      AL    Covington County       37886                  36444.0
# 20      AL     Crenshaw County       13938                  36022.0
# 21      AL      Cullman County       80965                  38971.0
# 22      AL         Dale County       49866                  45028.0
# 23      AL       Dallas County       42154                  27306.0
# 24      AL       Elmore County       80763                  53555.0
# 25      AL     Escambia County       37935                  32330.0
# 26      AL       Etowah County      103766                  39220.0
# 27      AL      Fayette County       16896                  34680.0
# 28      AL     Franklin County       31634                  35372.0
# 29      AL       Geneva County       26815                  36024.0
# ...    ...                 ...         ...                      ...
# 2776    WV       Upshur County       24560                  40330.0
# 2777    WV        Wayne County       41499                  36318.0
# 2778    WV      Webster County        8927                  29086.0
# 2779    WV       Wetzel County       16157                  39096.0
# 2780    WV         Wirt County        5841                  39352.0
# 2781    WV         Wood County       86559                  41884.0
# 2782    WV      Wyoming County       22866                  33730.0
# 2783    WY       Albany County       37565                  42834.0
# 2784    WY     Big Horn County       11895                  51679.0
# 2785    WY     Campbell County       48013                  80060.0
# 2786    WY       Carbon County       15739                  56825.0
# 2787    WY     Converse County       14101                  62307.0
# 2788    WY        Crook County        7229                  60445.0
# 2789    WY      Fremont County       40755                  52773.0
# 2790    WY       Goshen County       13544                  42689.0
# 2791    WY  Hot Springs County        4809                  45278.0
# 2792    WY      Johnson County        8600                  54065.0
# 2793    WY      Laramie County       95431                  60706.0
# 2794    WY      Lincoln County       18316                  66647.0
# 2795    WY      Natrona County       80011                  56871.0
# 2796    WY     Niobrara County        2516                  40398.0
# 2797    WY         Park County       28985                  56363.0
# 2798    WY       Platte County        8750                  38500.0
# 2799    WY     Sheridan County       29738                  55455.0
# 2800    WY     Sublette County       10117                  81772.0
# 2801    WY   Sweetwater County       44772                  69022.0
# 2802    WY        Teton County       22311                  75325.0
# 2803    WY        Uinta County       20930                  56569.0
# 2804    WY     Washakie County        8400                  47652.0
# 2805    WY       Weston County        7152                  57738.0
#
#       Unemployment Rate  Diversity-Index  White  Black  Hispanic/ Latino  \
# 0              5.417284         0.388898   75.9   18.4               2.7
# 1              5.364198         0.297942   83.1    9.5               4.6
# 2              8.460185         0.556605   46.3   47.6               4.8
# 3              7.684877         0.394100   74.6   22.1               2.1
# 4              5.164506         0.221056   87.8    1.8               8.7
# 5             11.433951         0.455794   22.2   69.9               7.8
# 6              9.816049         0.523370   53.5   43.6               1.2
# 7              6.962037         0.420387   73.1   20.9               3.5
# 8              7.932099         0.517068   57.4   39.1               2.0
# 9              6.198457         0.154772   91.8    4.5               1.5
# 10             6.320370         0.332047   80.7   10.3               7.7
# 11            10.123148         0.506220   55.8   42.7               0.7
# 12            10.695679         0.521338   53.2   44.2               1.3
# 13             7.364198         0.337811   80.0   14.4               3.3
# 14             5.903086         0.140602   92.6    3.6               2.2
# 15             5.711111         0.452732   71.5   17.5               6.6
# 16             7.711111         0.351218   78.8   16.4               2.5
# 17            10.173457         0.525778   51.2   46.0               1.7
# 18             7.416975         0.474980   65.3   31.3               2.1
# 19             7.412346         0.287773   83.4   12.7               1.6
# 20             7.291049         0.445408   70.4   24.1               1.8
# 21             5.841049         0.147579   92.2    1.4               4.4
# 22             6.258642         0.456053   70.8   19.6               5.7
# 23            11.775000         0.434200   28.5   69.6               0.9
# 24             5.304630         0.408283   73.9   21.1               2.8
# 25             8.031790         0.525935   60.7   32.2               2.1
# 26             7.119136         0.358120   78.5   15.5               3.6
# 27             7.737963         0.261504   85.1   11.8               1.5
# 28             7.969136         0.354606   78.7    4.3              15.4
# 29             6.210185         0.278204   84.3    9.8               3.4
# ...                 ...              ...    ...    ...               ...
# 2776           8.028704         0.070358   96.4    1.0               1.1
# 2777           7.083025         0.047278   97.6    0.4               0.6
# 2778          10.212346         0.045308   97.7    0.4               0.4
# 2779           9.905247         0.043370   97.8    0.4               0.7
# 2780          11.476852         0.053021   97.3    0.3               0.8
# 2781           6.480556         0.085603   95.6    1.2               0.9
# 2782           9.414506         0.049175   97.5    0.7               0.5
# 2783           3.109259         0.292300   83.5    2.0               9.3
# 2784           5.513889         0.226043   87.5    1.5               8.8
# 2785           4.173765         0.223414   87.7    1.1               8.2
# 2786           4.876235         0.357664   78.2    1.6              17.3
# 2787           4.567593         0.205170   88.8    1.2               7.6
# 2788           3.992593         0.118947   93.8    1.2               2.8
# 2789           6.208025         0.454651   70.5    0.9               6.5
# 2790           4.219753         0.240787   86.5    1.1              10.3
# 2791           4.450000         0.151642   92.0    0.9               3.6
# 2792           4.551543         0.158423   91.6    1.0               4.4
# 2793           4.360185         0.356937   78.8    3.6              14.1
# 2794           5.736111         0.143852   92.4    1.0               4.5
# 2795           5.100000         0.239113   86.8    1.9               8.0
# 2796           3.530556         0.133584   93.0    1.0               3.0
# 2797           4.532716         0.184256   90.1    1.5               5.8
# 2798           4.669753         0.197897   89.2    0.9               7.8
# 2799           4.823765         0.162154   91.4    1.2               4.3
# 2800           3.466667         0.218882   88.0    1.4               7.8
# 2801           4.749691         0.340296   79.6    1.7              15.9
# 2802           3.645062         0.325230   80.7    1.5              15.1
# 2803           5.538580         0.225552   87.5    0.8               9.1
# 2804           4.995062         0.296868   82.6    0.8              14.2
# 2805           4.448765         0.147697   92.2    0.6               3.8
#
#       Asian  American Indian  Native Hawaiian  Two or More Races
# 0       1.1              0.5              0.1                1.7
# 1       0.9              0.7              0.1                1.5
# 2       0.5              0.6              0.2                0.9
# 3       0.2              0.4              0.1                0.9
# 4       0.3              0.6              0.1                1.1
# 5       0.3              0.8              0.8                1.0
# 6       1.0              0.4              0.0                0.7
# 7       0.8              0.5              0.1                1.6
# 8       0.7              0.2              0.1                1.1
# 9       0.2              0.5              0.0                1.5
# 10      0.4              0.5              0.2                1.1
# 11      0.3              0.2              0.0                0.5
# 12      0.5              0.4              0.0                0.8
# 13      0.2              0.6              0.0                1.8
# 14      0.2              0.4              0.1                1.1
# 15      1.5              1.4              0.4                2.5
# 16      0.5              0.6              0.0                1.6
# 17      0.2              0.4              0.0                1.3
# 18      0.2              0.7              0.2                1.2
# 19      0.5              0.6              0.0                1.5
# 20      1.7              0.5              0.1                1.6
# 21      0.5              0.6              0.0                1.2
# 22      1.3              0.8              0.1                2.8
# 23      0.5              0.2              0.0                0.7
# 24      0.7              0.4              0.1                1.5
# 25      0.3              3.5              0.1                1.6
# 26      0.8              0.6              0.3                1.5
# 27      0.3              0.4              0.0                1.1
# 28      0.3              1.5              0.1                1.5
# 29      0.4              0.9              0.1                1.7
# ...     ...              ...              ...                ...
# 2776    0.4              0.3              0.0                1.0
# 2777    0.2              0.3              0.0                0.9
# 2778    0.3              0.1              0.0                1.1
# 2779    0.4              0.1              0.0                0.8
# 2780    0.2              0.2              0.0                1.3
# 2781    0.6              0.2              0.0                1.4
# 2782    0.1              0.2              0.0                1.1
# 2783    2.9              1.0              0.1                2.2
# 2784    0.5              1.3              0.0                1.3
# 2785    0.5              1.5              0.1                1.9
# 2786    0.9              1.7              0.1                1.6
# 2787    0.5              1.2              0.1                1.4
# 2788    0.2              0.9              0.0                1.4
# 2789    0.5             20.8              0.0                2.7
# 2790    0.6              1.0              0.1                1.1
# 2791    0.6              1.7              0.0                1.6
# 2792    0.8              1.5              0.0                1.4
# 2793    1.3              1.2              0.2                2.5
# 2794    0.5              1.0              0.1                1.1
# 2795    0.8              1.4              0.1                2.1
# 2796    0.4              1.0              0.0                2.0
# 2797    0.8              0.8              0.1                1.5
# 2798    0.5              0.7              0.2                1.4
# 2799    0.8              1.4              0.1                1.4
# 2800    1.1              1.1              0.0                1.4
# 2801    0.9              1.2              0.2                1.7
# 2802    1.3              1.0              0.1                1.5
# 2803    0.4              1.3              0.2                1.7
# 2804    0.7              1.7              0.1                1.7
# 2805    0.3              1.7              0.0                2.1
#
# [2806 rows x 13 columns]

# %% [markdown]
# ## === Exporting to SQL ===

# %%
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
engine = create_engine("mysql://root:@localhost/ETLProject")

# %%
merged_final_sql = merged_final.rename(columns={"Median household income":"MedianHouseHoldIncome",
                                               "Unemployment Rate":"UnemploymentRate",
                                               "Diversity-Index":"DiversityIndex",
                                               "Hispanic/ Latino":"Hispanic",
                                               "American Indian":"AmericanIndian",
                                               "Native Hawaiian":"NativeHawaiian",
                                               "Two or More Races":"TwoOrMore"})

# %%
merged_final_sql.head()
# Out:
#   State          County  Population  MedianHouseHoldIncome  UnemploymentRate  \
# 0    AL  Autauga County       55221                51281.0          5.417284
# 1    AL  Baldwin County      195121                50254.0          5.364198
# 2    AL  Barbour County       26932                32964.0          8.460185
# 3    AL     Bibb County       22604                38678.0          7.684877
# 4    AL   Blount County       57710                45813.0          5.164506
#
#    DiversityIndex  White  Black  Hispanic  Asian  AmericanIndian  \
# 0        0.388898   75.9   18.4       2.7    1.1             0.5
# 1        0.297942   83.1    9.5       4.6    0.9             0.7
# 2        0.556605   46.3   47.6       4.8    0.5             0.6
# 3        0.394100   74.6   22.1       2.1    0.2             0.4
# 4        0.221056   87.8    1.8       8.7    0.3             0.6
#
#    NativeHawaiian  TwoOrMore
# 0             0.1        1.7
# 1             0.1        1.5
# 2             0.2        0.9
# 3             0.1        0.9
# 4             0.1        1.1

# %%
merged_final_sql.to_sql(name='counties', con=engine, if_exists='append', index=False)
# Out:
# /Users/madhu/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
